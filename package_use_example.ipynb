# %%
# Data generator

import numpy as np
import matplotlib.pyplot as plt 

x = np.linspace(0, 1, 1000)

a0 = 4.02
a1 = 31.42
a2 = 11
a3 = 10
a4 = 11

y = [a0 + a1*i + a2 * np.sin(a3*i+a4) for i in x]
y = [i + np.random.normal(0,5) + np.exp(np.random.normal(0,1.3)) for i in y]

# %%
from sigmclipfit.sgmfit import sgmfit

i_val = [1, 10, 10, 10, 5] 
def fun(x, a0, a1, a2, a3, a4):
    return a0 + a1 * x + a2 * np.sin( a3 * x + a4)


fit = sgmfit(x, y, fun, i_val, 1.8)
fit.fit_model()
fit.fit_plot()

fit.result
# Out:
# <h2> Model</h2> Model(fun) <h2>Fit Statistics</h2><table><tr><td>fitting method</td><td>leastsq</td><td></td></tr><tr><td># function evals</td><td>13</td><td></td></tr><tr><td># data points</td><td>554</td><td></td></tr><tr><td># variables</td><td>5</td><td></td></tr><tr><td>chi-square</td><td> 2920.03520</td><td></td></tr><tr><td>reduced chi-square</td><td> 5.31882549</td><td></td></tr><tr><td>Akaike info crit.</td><td> 930.851189</td><td></td></tr><tr><td>Bayesian info crit.</td><td> 952.437013</td><td></td></tr></table><h2>Variables</h2><table><tr><th> name </th><th> value </th><th> standard error </th><th> relative error </th><th> initial value </th><th> min </th><th> max </th><th> vary </th></tr><tr><td> a0 </td><td>  7.48439968 </td><td>  0.28525770 </td><td> (3.81%) </td><td> 7.422319699231111 </td><td>        -inf </td><td>         inf </td><td> True </td></tr><tr><td> a1 </td><td>  29.9067770 </td><td>  0.51602253 </td><td> (1.73%) </td><td> 30.000197407474175 </td><td>        -inf </td><td>         inf </td><td> True </td></tr><tr><td> a2 </td><td>  10.6790133 </td><td>  0.14136818 </td><td> (1.32%) </td><td> 10.6466787725887 </td><td>        -inf </td><td>         inf </td><td> True </td></tr><tr><td> a3 </td><td>  9.91627281 </td><td>  0.07302111 </td><td> (0.74%) </td><td> 9.908669404704114 </td><td>        -inf </td><td>         inf </td><td> True </td></tr><tr><td> a4 </td><td>  4.67330217 </td><td>  0.03872605 </td><td> (0.83%) </td><td> 4.677364930683534 </td><td>        -inf </td><td>         inf </td><td> True </td></tr></table><h2>Correlations (unreported correlations are < 0.100)</h2><table><tr><td>a3</td><td>a4</td><td>-0.9359</td></tr><tr><td>a0</td><td>a1</td><td>-0.9324</td></tr><tr><td>a1</td><td>a3</td><td>-0.7375</td></tr><tr><td>a1</td><td>a4</td><td>0.6936</td></tr><tr><td>a0</td><td>a3</td><td>0.6888</td></tr><tr><td>a0</td><td>a4</td><td>-0.6856</td></tr><tr><td>a1</td><td>a2</td><td>-0.1526</td></tr><tr><td>a0</td><td>a2</td><td>0.1068</td></tr></table>
